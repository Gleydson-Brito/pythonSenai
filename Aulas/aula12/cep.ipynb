# %%
import requests 

cep = '72255605'

link = f'https://viacep.com.br/ws/{cep}/json/'

resposta = requests.get(link)

endereco = resposta.json()

endereco['numero'] = str(input('Digite o número da casa: '))
print(endereco)
# Out:
# {'cep': '72255-605', 'logradouro': 'Quadra QNO 15 Conjunto E', 'complemento': '', 'unidade': '', 'bairro': 'Ceilândia Norte (Ceilândia)', 'localidade': 'Brasília', 'uf': 'DF', 'ibge': '5300108', 'gia': '', 'ddd': '61', 'siafi': '9701', 'numero': '48'}
